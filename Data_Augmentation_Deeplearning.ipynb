# %%
import tensorflow as tf
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PATH =  "/content/drive/My Drive/Data Centric Approach/test_img/train/"

# %%
def img_augmentation(src):
    tf.keras.preprocessing.image_dataset_from_directory(
    src,
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="grayscale",
    batch_size=32,
    image_size=(32, 32),
    shuffle=True,
    seed=None,
    validation_split=0,
    interpolation="bilinear",
    follow_links=False
)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
def augmentation(source,labels,image_size):
    datagen = ImageDataGenerator(
            # rotation_range=40,
            width_shift_range=0.2,
            height_shift_range=0.2,
            shear_range=0.2,
            zoom_range=0.5,
            horizontal_flip=True,
            fill_mode='nearest',
            brightness_range=(0.0,1.5),
            # vertical_flip=True
            )
    for label in labels:
        src=source + label+"/"
        print("Image augmentation of Label-{} at source-{}".format(label,src))
        for img in tqdm(os.listdir(src)):
            # try:
                img = load_img(src+img,0)  # this is a PIL image
                # img=cv2.imread(src+img,1)
                # img=cv2.Canny(img,50,150)
                # img=cv2.resize(img,(image_size,image_size))
                # img_arr = img_to_array(img)
                # img_arr = img_arr.reshape((1,) + img_arr.shape)
                i = 0

                for batch in datagen.flow(
                    img,
                    batch_size=1,
                    save_to_dir=src,
                    save_prefix=label,
                    save_format='jpg'):
                    if i > 5:
                        break
                    i += 1
            # except:
            #     print(img)

# %%
import os,cv2
from tqdm import tqdm
labels = os.listdir(PATH)

# %%
augmentation(PATH,labels,32,)

# %%
labels
# Out:
# ['i', 'x', 'v']

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
image

# %%
import matplotlib.pyplot as plt,numpy as np
from skimage import io
plt.figure(figsize=(10, 10))
# for i in range(9):
image = PATH + labels[0] + os.listdir(PATH + labels[0])[0]
image = cv2.imread('/content/drive/My Drive/Data Centric Approach/test_img/train/x/b2f40e72-ce5d-11eb-b317-38f9d35ea60f.png')
image = tf.convert_to_tensor(image, dtype=tf.float32)
image = tf.expand_dims(image,0)
augmented_image = data_augmentation(image)
plt.imshow(augmented_image[0])
plt.axis("off")
cv2.imwrite('/content/drive/My Drive/Data Centric Approach/test_img/train/x/test.png',image.numpy())
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# False

# %%
np.array(augmented_image)
# Out:
# array([[[[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         ...,
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
# ...

# %%
PATH+labels[0]
# Out:
# '/content/drive/My Drive/Data Centric Approach/test_img/train/x'

# %%
augmented_image
# Out:
# <tf.Tensor: shape=(1, 313, 314, 3), dtype=float32, numpy=
# array([[[[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         ...,
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
# ...
